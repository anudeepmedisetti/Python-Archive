# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv('banana.csv')
X=data.iloc[:,0:2].values
y=data.iloc[:,-1].values
print(X)
print(y)
#colors = np.array([x for x in "bgrcmyk"])
plt.scatter(X[:, 0], X[:, 1], c='b',s=1)
plt.title('Scatter plot')
plt.xlabel('(X[:, 0]')
plt.ylabel('(X[:, 1]')
plt.show()
# Out:
# [[ 1.14  -0.114]
#  [-1.52  -1.15 ]
#  [-1.05   0.72 ]
#  ...
#  [ 2.64   1.14 ]
#  [ 0.769  0.772]
#  [-0.255 -0.142]]
# [-1  1 -1 ...  1 -1  1]

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=0).fit(X)
kmeans.labels_
z=kmeans.labels_
#kmeans.cluster_centers_

# %%
z
# Out:
# array([0, 1, 2, ..., 0, 0, 1])

# %%
colors = np.array([x for x in "bgrcmyk"])
plt.scatter(X[:, 0], X[:, 1], color=colors[list(z)].tolist(), s=1)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 1.11722562,  0.13769533],
#        [-0.62117013, -0.87199325],
#        [-0.38569085,  1.06507229]])

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)
kmeans.labels_
a=kmeans.labels_
#kmeans.cluster_centers_

# %%
a
# Out:
# array([1, 0, 0, ..., 1, 1, 0])

# %%
plt.scatter(X[:, 0], X[:, 1], color=colors[list(a)].tolist(), s=1)

# %%
print(y)
# Out:
# [-1  1 -1 ...  1 -1  1]

# %%
for i in range(len(y)):
    if y[i] == -1:
        y[i] = 0
print(y)
# Out:
# [0 1 0 ... 1 0 1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, random_state=42)
colors = np.array([x for x in "bgrcmyk"])
plt.scatter(X_train[:, 0], X_train[:, 1], c=colors[list(y_train)])
plt.title('Scatter plot')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
from sklearn.neighbors import KNeighborsClassifier
from sklearn import neighbors
from sklearn.metrics import accuracy_score
knn = neighbors.KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

print(accuracy_score(y_test, y_pred))
# Out:
# 0.8893867924528301

# %%
len(X_train)
print(X_train)
# Out:
# [[ 0.962  0.851]
#  [-1.98   0.345]
#  [ 1.12   1.14 ]
#  ...
#  [-1.36  -0.848]
#  [ 0.631 -0.674]
#  [-0.314 -0.984]]

# %%
length=range(1,len(X_train))

# %%
accuracy=[];
results=[];
for i in range(1,len(X_train),100):
    knn = neighbors.KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    accuracy.append(accuracy_score(y_test, y_pred))
    results.append([i,accuracy_score(y_test, y_pred)])
    print(accuracy_score(y_test, y_pred))
# Out:
# 0.867688679245283
# 0.8509433962264151
# 0.8132075471698114
# 0.7433962264150943
# 0.6983490566037736
# 0.46462264150943394
# 0.41297169811320755
# 0.4733490566037736
# 0.4235849056603774
# 0.558254716981132
# 0.5547169811320755

# %%
print(results)
# Out:
# [[1, 0.867688679245283], [101, 0.8509433962264151], [201, 0.8132075471698114], [301, 0.7433962264150943], [401, 0.6983490566037736], [501, 0.46462264150943394], [601, 0.41297169811320755], [701, 0.4733490566037736], [801, 0.4235849056603774], [901, 0.558254716981132], [1001, 0.5547169811320755]]

# %%
array = np.array((results))

# %%
import matplotlib.pyplot as plt1
plt1.plot(array[:,0], array[:,1])
plt1.show()

# %%
accuracy=[];
results=[];
for i in range(1,200,50):
    knn = neighbors.KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    accuracy.append(accuracy_score(y_test, y_pred))
    results.append([i,accuracy_score(y_test, y_pred)])
    print(accuracy_score(y_test, y_pred))
array = np.array((results))
import matplotlib.pyplot as plt1
plt1.plot(array[:,0], array[:,1])
plt1.show()
# Out:
# 0.867688679245283
# 0.8929245283018868
# 0.8509433962264151
# 0.8367924528301887

# %%
accuracy=[];
results=[];
for i in range(1,60,10):
    knn = neighbors.KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    accuracy.append(accuracy_score(y_test, y_pred))
    results.append([i,accuracy_score(y_test, y_pred)])
    print(accuracy_score(y_test, y_pred))
array = np.array((results))
import matplotlib.pyplot as plt1
plt1.plot(array[:,0], array[:,1])
plt1.show()
# Out:
# 0.867688679245283
# 0.8952830188679245
# 0.8962264150943396
# 0.8945754716981132
# 0.8915094339622641
# 0.8929245283018868

# %%
accuracy=[];
results=[];
for i in range(1,20):
    knn = neighbors.KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    accuracy.append(accuracy_score(y_test, y_pred))
    results.append([i,accuracy_score(y_test, y_pred)])
    print(accuracy_score(y_test, y_pred))
array = np.array((results))
import matplotlib.pyplot as plt1
plt1.plot(array[:,0], array[:,1])
plt1.show()
# Out:
# 0.867688679245283
# 0.8816037735849057
# 0.8893867924528301
# 0.8915094339622641
# 0.8929245283018868
# 0.8971698113207547
# 0.8952830188679245
# 0.9007075471698113
# 0.8985849056603774
# 0.8985849056603774
# 0.8952830188679245
# 0.897877358490566
# 0.8955188679245283
# 0.8976415094339623
# 0.8976415094339623
# 0.8976415094339623
# 0.894811320754717
# 0.8971698113207547
# 0.8962264150943396

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors=8)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
accuracy.append(accuracy_score(y_test, y_pred))
results.append([i,accuracy_score(y_test, y_pred)])
print(accuracy_score(y_test, y_pred))from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=0).fit(X)
kmeans.labels_
z=kmeans.labels_
# Out:
# 0.9007075471698113

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=8, random_state=0).fit(X)
kmeans.labels_
k1=kmeans.labels_
print(k1)
colors = np.array([x for x in "bgrcmykb"])
plt.scatter(X[:, 0], X[:, 1], color=colors[list(k1)].tolist(), s=1)
# Out:
# [6 3 0 ... 2 2 5]
